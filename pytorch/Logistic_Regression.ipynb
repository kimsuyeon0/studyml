# %% [markdown]
# <a href="https://colab.research.google.com/github/kimsuyeon0/studyml/blob/master/pytorch/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Logistic Regression
#
# - 이진 분류에 쓰인다.
# - x-> linear ->y' 에서 x-> linear -> sigmoid -> y' 형태
# - 선형모델의 출력값에 시그모이드를 추가
# - 시그모이드는 모든 숫자가 0-1사이로 압축되어있다고 생각하면 된다.
# - 가장 간단한 방법은 0.5 라는 임계값을 주는 것이다 0.5보다 작으면 0 크면 1로.

# %%
import torch
from torch.autograd import Variable
import torch.nn.functional as F

# %%
x_data = Variable(torch.Tensor([[1.0], [2.0], [3.0], [4.0]]))
y_data = Variable(torch.Tensor([[0.], [0.], [1.], [1.]]))

# %%
class Model(torch.nn.Module):
  def __init__(self):
    super(Model, self).__init__()
    self.linear=torch.nn.Linear(1,1)
    
  def forward(self, x):
    y_pred=F.sigmoid(self.linear(x))
    return y_pred

# %%
model=Model()

# %%
criterion=torch.nn.BCELoss(size_average=True)
optimizer=torch.optim.SGD(model.parameters(), lr=0.01)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:49: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %%
for epoch in range(1000):
  y_pred=model(x_data)
  
  loss=criterion(y_pred, y_data)
  print(epoch, loss.item())
  
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1332: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 0 0.7876983284950256
# 1 0.7847951054573059
# 2 0.7819358110427856
# 3 0.7791202664375305
# 4 0.7763481140136719
# 5 0.7736191749572754
# 6 0.7709333896636963
# 7 0.7682901620864868
# 8 0.765689492225647
# 9 0.7631308436393738
# 10 0.7606140375137329
# 11 0.7581386566162109
# 12 0.7557045817375183
# 13 0.753311038017273
# 14 0.7509582042694092
# 15 0.7486453056335449
# 16 0.7463721036911011
# 17 0.7441381216049194
# 18 0.7419432401657104
# 19 0.7397867441177368
# 20 0.7376683354377747
# 21 0.7355876564979553
# 22 0.7335442900657654
# 23 0.7315375804901123
# 24 0.7295674681663513
# 25 0.7276330590248108
# 26 0.7257344126701355
# 27 0.7238706350326538
# 28 0.7220413684844971
# 29 0.7202463746070862
# 30 0.7184849977493286
# 31 0.7167565226554871
# ...

# %%
hour_var = Variable(torch.Tensor([[1.0]]))
print("predict 1 hour ", 1.0, model(hour_var).data[0][0] > 0.5)
hour_var = Variable(torch.Tensor([[7.0]]))
print("predict 7 hours", 7.0, model(hour_var).data[0][0] > 0.5)
# Out:
# predict 1 hour  1.0 tensor(0, dtype=torch.uint8)
# predict 7 hours 7.0 tensor(1, dtype=torch.uint8)
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1332: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %% [markdown]
# 1) 클래스를 통해 모델디자인
#
# 2) 손실함수와 옵티마이저 정의
#
# 3) 훈련루프
